# %%
from json.decoder import NaN

import pandas
sales = pandas.read_csv('sales.csv')
returns = pandas.read_csv('returns.csv')
svodnaya = pandas.merge(sales, returns, on='order_id')
svodnaya.head(10)
# Out:
#    order_id        date  customer_id         category               region  \
# 0  59570135  2017-10-16          512   Одежда и обувь  Ставропольский край
# 1  16578697  2017-07-18          512   Одежда и обувь  Ставропольский край
# 2  46943601  2017-07-05          512  Бытовая техника  Ставропольский край
# 3  42436035  2017-02-18          512    Спорт и отдых  Ставропольский край
# 4  49798299  2017-09-08          512          Красота  Ставропольский край
# 5  85282012  2017-01-01          512           Аптека  Ставропольский край
# 6  86441447  2017-07-04          513    Спорт и отдых   Московская область
# 7   3468527  2017-05-31          513           Аптека   Московская область
# 8  82105305  2017-03-30          513    Спорт и отдых   Московская область
# 9  23201528  2017-04-22          513           Аптека   Московская область
#
#    sales  quantity  discount  return
# 0   1301         2      0.00       0
# 1   3530         4      0.05       0
# ...

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1554192 entries, 0 to 1554191
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   order_id     1554192 non-null  int64
#  1   date         1554192 non-null  str
#  2   customer_id  1554192 non-null  int64
#  3   category     1554192 non-null  str
#  4   region       1554192 non-null  str
#  5   sales        1554192 non-null  int64
#  6   quantity     1554192 non-null  int64
#  7   discount     1554192 non-null  float64
# dtypes: float64(1), int64(4), str(3)
# memory usage: 94.9 MB

# %%
svodnaya.describe()
# Out:
#            order_id   customer_id         sales      quantity      discount  \
# count  1.578056e+06  1.578056e+06  1.578056e+06  1.578056e+06  1.578056e+06
# mean   4.996719e+07  5.044904e+04  4.113202e+03  2.500878e+00  3.000557e-02
# std    2.888277e+07  2.885800e+04  4.414647e+03  1.036815e+00  3.652440e-02
# min    7.700000e+01  5.120000e+02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.493304e+07  2.545900e+04  1.136000e+03  2.000000e+00  0.000000e+00
# 50%    4.996321e+07  5.040300e+04  2.516000e+03  2.000000e+00  0.000000e+00
# 75%    7.501090e+07  7.542800e+04  5.315000e+03  3.000000e+00  5.000000e-02
# max    9.999999e+07  1.005110e+05  4.200700e+04  8.000000e+00  1.000000e-01
#
#              return
# count  1.578056e+06
# mean   2.516463e-01
# std    4.339592e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00

# %%
svodnaya [ (svodnaya['category'] == 'Одежда и обувь') | (svodnaya['category'] == 'Бытовая техника') ].head(20)
svodnaya.groupby('region').agg({'sales':'sum'}).sort_values('sales',ascending=False)
# Out:
#                            sales
# region
# Амурская область       915306174
# Московская область     907914759
# Хабаровский край       726539996
# Ленинградская область  725728347
# Приморский край        554908493
# Краснодарский край     550315968
# Иркутская область      545630058
# Ставропольский край    455428458
# Владимирская область   374115860
# Красноярский край      371467982
# Смоленская область     363506596

# %%
import pandas
import matplotlib

swd = pandas.read_csv('sales_with_duplicates.csv')
swd['sales'].hist()
# Out:
# <Axes: >
